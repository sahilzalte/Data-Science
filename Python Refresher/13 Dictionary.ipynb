# %%
d = {}

# %%
# Dictionary with key-value pairs
student = {
    "name": "Alice",
    "age": 25,
    "grade": "A"
}

# %%
student["name"]
# Out:
# 'Alice'

# %%
student["name2"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 student["name2"]
#
# KeyError: 'name2'

# %%
r=student.get("name3")

# %%
print(r)
# Out:
# None

# %%
student = {
    "name": "Alice",
    "age": 25,
    "grade": "A"
}

# %%
print(student["age"])
# Out:
# 25

# %%
student["age"] = 76

# %%
student["age"]
# Out:
# 76

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student.values()
# Out:
# dict_values(['Alice', 76, 'A'])

# %%
student.items()
# Out:
# dict_items([('name', 'Alice'), ('age', 76), ('grade', 'A')])

# %%
student.update({"name":"Sahil"})

# %%
student["name"]
# Out:
# 'Sahil'
