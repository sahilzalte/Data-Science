# %% [markdown]
# # Python Operators
#
# A quick refresher on the main operator groups in Python.
#
# ## Arithmetic Operators
#
# Use these to perform basic math operations on numeric values.

# %%
a = 11
b = 5

# %%
a + b
# Out:
# 16

# %%
a-b
# Out:
# 6

# %%
a *b
# Out:
# 55

# %%
a/b
# Out:
# 2.2

# %%
a//b
# Out:
# 2

# %%
2**2
# Out:
# 4

# %%
2**5
# Out:
# 32

# %%
a**b
# Out:
# 161051

# %%
a%b
# Out:
# 1

# %% [markdown]
# ## Comparison Operators
#
# These operators compare values and return `True` or `False`.

# %%
a = 45

# %%
b = 4

# %%
a<b
# Out:
# False

# %%
a>b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
c = 3

# %%
a == c # is a equal to c?
# Out:
# False

# %%
a != c
# Out:
# True

# %%
a = 5
b = 5

# %%
a == b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# True

# %%
b1 = True
b2 = False

# %%
not(b1)
# Out:
# False

# %%
not(b2)
# Out:
# True

# %% [markdown]
# ## Assignment Operators
#
# Assignment operators update the value of a variable in place.

# %%
b1 or b2
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %% [markdown]
# ## Logical Operators
#
# Logical operators combine boolean values and expressions.

# %%
a = 45

# %%
a -=4

# %%
a
# Out:
# 41

# %%
11//2
# Out:
# 5

# %%
a = 11

# %%
a //=2

# %%
a
# Out:
# 5
