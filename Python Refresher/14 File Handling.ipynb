# %%
f = open("Main.txt",'r')

# %%
f.read()
# Out:
# 'dsad'

# %%
s = "Sample Text"

# %%
 f.close()

# %%
f = open("Sahil.txt","a")

# %%
f = open("Sahil.txt", "a")
f.write("\nThis is an additional line.")
f.close()  # <-- This forces the buffer to save to disk

# %%
f1 = open("Sahil.txt",'r')

# %%
f1 = open("Sahil.txt", "r")
f1.read()
# Out:
# 'Sample Text\nThis is an additional line.\nThis is an additional line.\nThis is an additional line.\nThis is an additional line.\nThis is an additional line.'
