# %%
n = [3,4,5,67]

# %%
for itm in n:
    print(itm)
# Out:
# 3
# 4
# 5
# 67

# %%
for i in range(1,10):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
count = 0
while count <= 3:
    print(count)
    count += 1
# Out:
# 0
# 1
# 2
# 3

# %%
for i in range(5):
    if i == 3:
        break  # Stops the loop at 3
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(5):
    if i == 3:
        pass
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):
    if i == 3:
       continue
    print(i)
# Out:
# 0
# 1
# 2
# 4
