# %% [markdown]
# # Python Basics
#
# A simple notebook covering variables, arithmetic, strings, and type casting.

# %% [markdown]
# ## Basic Variables and Arithmetic
#
# Start with simple assignments and addition.

# %%
a = 9

# %%
b = 40

# %%
a+b
# Out:
# 49

# %% [markdown]
# ## Variables and Output
#
# Create a string variable and print a simple message.

# %%
Name = "Sahhil"

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ## Comments
#
# Comments in Python start with `#`.

# %% [markdown]
# ## Type Checking
#
# Check the types of the numeric and string variables.

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(Name))
# Out:
# <class 'str'>

# %%
type(Name)
# Out:
# str

# %%
ab="2345"

# %% [markdown]
# ## String Concatenation and Type Casting
#
# Combine strings and convert them to integers before adding.

# %%
cd="3253"

# %%
ab+cd
# Out:
# '23453253'

# %%
int(ab)+int(cd) # typecasting
# Out:
# 5598
