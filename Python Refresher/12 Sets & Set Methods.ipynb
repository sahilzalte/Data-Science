# %%
a = {}

# %%
type(a)
# Out:
# dict

# %%
b = set()

# %%
type(b)
# Out:
# set

# %%
s = {12,233,43,22,53,34}

# %%
s
# Out:
# {12, 22, 34, 43, 53, 233}

# %%
# Creating a set from a list
unique_numbers = set([1, 2, 2, 3, 4, 4, 5])
print(unique_numbers)  # {1, 2, 3, 4, 5}
# Out:
# {1, 2, 3, 4, 5}

# %%
s = {12,233,43,22,53,34}

# %%
s.add(34)

# %%
s
# Out:
# {12, 22, 34, 43, 53, 233}

# %%
s.update([34,35,35,645,356,55])

# %%
s
# Out:
# {12, 22, 34, 35, 43, 53, 55, 233, 356, 645}

# %%
s.remove(22)

# %%
s
# Out:
# {12, 34, 35, 43, 53, 55, 233, 356, 645}

# %%
s.remove(555)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 s.remove(555)
#
# KeyError: 555

# %%
s.discard(555)

# %%
s.pop()
# Out:
# 645

# %%
m=s.copy()

# %%
m
# Out:
# {12, 34, 35, 43, 53, 55, 233, 356}

# %%
m.pop()
# Out:
# 34

# %%
s
# Out:
# {12, 34, 35, 43, 53, 55, 233, 356}

# %%
m.pop()
# Out:
# 35

# %%
m
# Out:
# {12, 43, 53, 55, 233, 356}

# %%
s
# Out:
# {12, 34, 35, 43, 53, 55, 233, 356}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}

# %%
set1.union(set2) # both combined
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1.intersection(set2) # element having in both sets
# Out:
# {3, 4}

# %%
sub = {1,3}

# %%
sub.issubset(set1)
# Out:
# True

# %%
set1.issuperset(sub)
# Out:
# True
