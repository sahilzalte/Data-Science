# %% [markdown]
# # Operator Precedence in Python
#
# Python evaluates expressions using a fixed order of operations. This notebook shows how that order changes the result of arithmetic expressions.
#
# ## Precedence Order
#
# Python generally follows this order:
#
# 1. Parentheses `()`
# 2. Exponents `**`
# 3. Multiplication `*`, division `/`, floor division `//`, and modulus `%`
# 4. Addition `+` and subtraction `-`
#
# ## Example 1: Basic Precedence
#
# ```python
# result = 10 + 2 * 3  # Multiplication happens first: 10 + (2 * 3) = 16
# print(result)
# ```

# %%
result = 10 + 2 * 3

# %%
result
# Out:
# 16

# %%
54*3/23+4-2**5
# Out:
# -20.956521739130434

# %% [markdown]
# ## Example 2: Combined Expressions
#
# These expressions show how Python reduces multiple operators in a single line.

# %%
54*3/23+4-32
# Out:
# -20.956521739130434

# %%
162/23+4-32
# Out:
# -20.956521739130434

# %%
7.04+4-32
# Out:
# -20.96

# %% [markdown]
# ### Order of Evaluation
#
# 1. **Exponentiation (`**`) is evaluated right to left**.
#    - Example:
#      ```python
#      print(2 ** 3 ** 2)  # Output: 512
#      ```
#      This is evaluated as `2 ** (3 ** 2)`, meaning `2 ** 9 = 512`.
#
# 2. **Multiplication (`*`), division (`/`), floor division (`//`), and modulo (`%`) are evaluated left to right**.
#    - Example:
#      ```python
#      print(16 / 4 * 2)  # Output: 8.0
#      ```
#      This is evaluated as `(16 / 4) * 2 = 4.0 * 2 = 8.0`.
#
# ### Operator Precedence Summary:
# - `**` (Exponentiation) has the **highest precedence** and is evaluated **right to left**.
# - `*`, `/`, `//`, and `%` have lower precedence than `**` but are evaluated **left to right**.
